# %% [markdown]
# # Mod 3 Project- County Population Effects on Median Income and Unemployment:

# %% [markdown]
# ## Ben Geissel & Rob Hermany

# %% [markdown]
# ## Non-Technical Audience Jupyter Notebook

# %% [markdown]
# In this project, we wanted to explore the effect of county population size and how that affected median household income and unemployment figures.
#
# We first extracted and cleaned data from the US Census Bureau API and USDA. We were able to gather data organized by county FIPS code. We merged these datasets to compile a master dataset including FIPS code, population size, population median income, and unemployment rates.
#
# In our analysis, we used a two tailed test to determine if county population size created a statistically significant change in mean, as compared to the US mean. For out samples, we binned county size into 3 cateogories: rural, mixed-suburban, and urban. We then evaluated our tests by comparing the p-values with our alpha (0.05)
# ____

# %% [markdown]
# First, we explored our population data. We compiled a distribution of county population median income. From this data, we observed that the national median income was normally distributed with a slightly right skew with a tail to the right of the distribution. This tells us that the national median income is closer to the 2nd quartile with a median less than mean. We found a median income across 3,141 counties of \\$51,090.53 and a standard deviation of \\$13,497.97

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We also compiled a distrubution of unemployment rates. We observed that this data was normally distributed. We observed an average unemployment rate of 4.60% with a standard deviation of 1.67%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Below is a figure of population size which visualizes our urban, mix/suburban, and rural county categories. Each category served as a sample from the larger population from which to conduct our hypothesis testing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# ###  Urban Counties:

# %% [markdown]
# To test if Urban county median income had any statistically signficant difference from the national median income we  formed our hypotheses.
#
#
# 𝐻0 : County median income is not affected by urban populations
#
# 𝐻1 : County median income is affected by urban populations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We observed an higher than national median income of $60,977 with a corresponding z score of .732 and p value of .232. Based on these figures, we failed to reject the null hypothesis.

# %% [markdown]
# To test if Urban county unemployment had any statistically signficant difference from national unemployment figures we  formed our hypotheses.

# %% [markdown]
# 𝐻0 : County unemployment rate is not affected by urban populations (pop_mean == urban_mean)
#
# 𝐻1 :  County unemployment rate is affected by urban populations (pop_mean ≠ urban_mean). We observed an x̄:  	4.35%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We observed a slgihtly lower unemployment rate than the national average at 4.35% with a correspodning z score of -.147% and p value of .558. Based on these figures, we also failed to reject the null hypothesis

# %% [markdown]
# ### Suburban / Mix County:

# %% [markdown]
# To test if Suburban county median income had any statistically signficant difference from the national median income we  formed our two hypotheses:

# %% [markdown]
# 𝐻0 : County median income is not affected by mixed / suburban populations
#
# 𝐻1 : County median income is affected by mixed / suburban populations. We observed an x̄:  	$50,167

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For suburban/mix counties we observed nearly identical medican incomes of \\$50,167 compared to a national average of \\$50,090.00. With a corresponding z score of -.06 and p avalue of -.52 we failed to reject the null hypothesis.

# %% [markdown]
# To test if Suburban county unemployment had any statistically signficant difference from national unemployment figures we  formed our two hypotheses:

# %% [markdown]
# 𝐻0 : County unemployment rate is not affected by mixed / suburban populations (pop_mean == mixed /suburban_mean)
#
# 𝐻1 :  County unemployment rate is affected by mixed suburban populations (pop_mean ≠  mixed /suburban_mean). x̄:  4.60%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We also observed little difference with unemployment figures. Average unemployment matched the national average; corresponding z score of .007 we failed to reject the null hypothesis

# %% [markdown]
# ### Rural County Distributions:

# %% [markdown]
# To test if rural county median income had any statistically signficant difference from the national median income we  formed our hypotheses.

# %% [markdown]
# 𝐻0 : County median income is not affected by rural populations
#
# 𝐻1 : County median income is affected by rural populations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For rural counties, we observed a slightly lower than national average for median income at \\$46,423 compared to a national average of \\$51,090.00. With a z score of -0.345 and p value of .635 we failed to reject the null hypothesis.

# %% [markdown]
# To test if rural county unemploymebnt had any statistically signficant difference from national unemployment we  formed our hypotheses.

# %% [markdown]
# 𝐻0 : County unemployment rate is not affected by rural populations (pop_mean == rural_mean)
#
# 𝐻1 :  County unemployment rate is affected by rural populations (pop_mean ≠ rural_mean)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Rural unemployment was slighly above the national average at 4.72% with a z score of .076 and p value of .469. Based on these figures we failed to reject the null hypohtesis.

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# Overall, we found that the population size of a county does not create a significantly different change in either median income or unemployment metrics
# Urban counties have a higher median income by \\$9k, lower unemployment rate by .35% from our sample
# Rural counties have a lower median income by \\$4k, higher unemployment rate by .20% from our sample
